# %% [markdown]
# ### Import Libraries

# %%
# Snowpark for Python
from snowflake.snowpark.session import Session
from snowflake.snowpark.functions import month,year,col,sum
from snowflake.snowpark.version import VERSION
# Misc
import json
import sys
import logging 
logger = logging.getLogger("snowflake.snowpark.session")
logger.setLevel(logging.ERROR)

# %%
# Create Snowflake Session object
connection_parameters = {
"account": "snowhouse",
"user": "sapatra",
"authenticator":"externalbrowser",
"role": "solution_architect",
"warehouse": "snowadhoc",
"database": "temp",
"schema": "util"
}
session = Session.builder.configs(connection_parameters).create()
session.sql_simplifier_enabled = True

snowflake_environment = session.sql('select current_user(), current_version()').collect()
snowpark_version = VERSION

# Current Environment Details
print('User                        : {}'.format(snowflake_environment[0][0]))
print('Role                        : {}'.format(session.get_current_role()))
print('Warehouse                   : {}'.format(session.get_current_warehouse()))
print('Snowflake version           : {}'.format(snowflake_environment[0][1]))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
# Out:
# User                        : SAPATRA
# Role                        : "SOLUTION_ARCHITECT"
# Warehouse                   : "SNOWADHOC"
# Snowflake version           : 7.11.6
# Snowpark for Python version : 1.0.0
# Database                    : "TEMP"
# Schema                      : "UTIL"

# %%
def account_usage_view_deploy(session: Session , deployment_name : str ,replication_group_value : str , schema_name : str ) -> str:   
    pandas_df = session.table('temp.util.account_usage_view_mapping').toPandas()
    #session.use_schema(schema_name)
    #session.sql(f"""use schema {schema_name}""").collect()
    try:
        for index,row in pandas_df.iterrows():
            vw_def=row['VIEW_DEFINITION']
            vw_name=row['VIEW_NAME']
            vw_name_schema=f"{schema_name}.{vw_name}"
            new_vw_def=vw_def.replace(vw_name,vw_name_schema)
            new_vw_def=new_vw_def.replace('deployment_name',deployment_name)
            new_vw_def=new_vw_def.replace('replication_group_value',replication_group_value)
            session.sql(new_vw_def).collect()
    except:
        print("error executin", sys.exc_info()[0], "occurred.")
    else:
        return new_vw_def
        
session.sproc.register(
  func=account_usage_view_deploy,
  name="account_usage_view_deploy",
  packages=['snowflake-snowpark-python'],
  is_permanent=True,
  #execute_as="CALLER",
  stage_location="@account_usage_sproc",
  replace=True)

# %%
pandas_df = session.table('temp.util.account_usage_view_mapping').toPandas()
schema='spatra'
for index,row in pandas_df.iterrows():
    vw_def=row['VIEW_DEFINITION']
    vw_name=row['VIEW_NAME']
    vw_name_schema=f"{schema}.{vw_name}"
    def1=vw_def.replace('deployment_name','ie')
    #def2=def1.str.lstrip('create or replace  view')
    new_vw_def=def1.replace(vw_name,vw_name_schema)
    print(new_vw_def)
    #print(vw_name_schema)
    #new_vw_def=new_vw_def.replace('replication_group_value',replication_group_value)
# Out:
# create or replace  view spatra.WAREHOUSE_EVENTS_HISTORY(
# 	TIMESTAMP,
# 	WAREHOUSE_ID,
# 	WAREHOUSE_NAME,
# 	CLUSTER_NUMBER,
# 	EVENT_NAME,
# 	EVENT_REASON,
# 	EVENT_STATE,
# 	USER_NAME,
# 	ROLE_NAME,
# 	QUERY_ID,
#     ACCOUNT_ID,
#     ACCOUNT_NAME
# ) as
# with cust_accounts as (select id from snowhouse_import.ie.account_etl_v where replication_group = 'replication_group_value')
#     , event_types AS
#     (
#         SELECT index::int AS id,
#           value::string AS name
#         FROM table(flatten(input => SELECT parse_json(system$dump_enum('WarehouseLogEventType'))))
#     ),
#     event_reasons AS
#     (
#         SELECT index::int AS id,
#              value::string AS name
#         FROM table(flatten(input => SELECT parse_json(system$dump_enum('WarehouseOperationReasons'))))
#     )
#      SELECT
#        (warehouselog.dpo:"WarehouseLogDPO:primary".timestamp::int/1000)::timestamp_ltz AS timestamp,
#        SNOWHOUSE.PS_TAM.extract_local_id(warehouselog.dpo:"WarehouseLogDPO:primary".warehouseId::int) AS warehouse_id,
#        warehouse.dpo:"WarehouseDPO:primary".name::string AS warehouse_name,
#        warehouselog.dpo:"WarehouseLogDPO:primary".clusterNumber::int AS cluster_number,
#        event_types.name AS event_name,
#        iff(event_reasons.name = 'INVALID', null, event_reasons.name) AS event_reason,
#        decode (warehouselog.dpo:"WarehouseLogDPO:primary".eventState::int,
#                   1,'STARTED',
#                   2,'SQUASHED',
#                   3,'COMPLETED',
#                   4,'PARTIALLY_COMPLETED',
#                   null
#                   ) AS event_state,
#        strip_null_value(warehouselog.dpo:"WarehouseLogDPO:primary".userName)::string as user_name,
#        strip_null_value(warehouselog.dpo:"WarehouseLogDPO:primary".roleName)::string as role_name,
#        strip_null_value(warehouselog.dpo:"WarehouseLogDPO:primary".jobUuid)::string as query_id,
#         warehouselog.dpo:"WarehouseLogDPO:primary".eventAccountId::int as account_id,
#         ACCOUNT_ETL_V.name as account_name
#     FROM SNOWHOUSE_IMPORT.ie.WAREHOUSE_LOG_ETL_v AS warehouselog
#     JOIN SNOWHOUSE_IMPORT.ie.ACCOUNT_ETL_V on warehouselog.dpo:"WarehouseLogDPO:primary".eventAccountId::int = ACCOUNT_ETL_V.ID
#     JOIN SNOWHOUSE_IMPORT.ie.warehouse_etl_v AS warehouse
#     ON warehouse.dpo:"WarehouseDPO:primary".id::int = warehouselog.dpo:"WarehouseLogDPO:primary".warehouseId::int
#     LEFT OUTER JOIN event_types
#     ON warehouselog.dpo:"WarehouseLogDPO:primary".eventType::int = event_types.id
#     LEFT OUTER JOIN event_reasons
#     ON warehouselog.dpo:"WarehouseLogDPO:primary".operationReasonId::int = event_reasons.id
#     WHERE warehouse.dpo:"WarehouseDPO:primary".accountId::int  in (select id from cust_accounts)
#       AND warehouselog.dpo:"WarehouseLogDPO:primary".eventAccountId::int  in (select id from cust_accounts)
#       AND warehouselog.dpo:"WarehouseLogDPO:primary".eventState::int != 2
#       AND timestamp >= dateadd(month, -12, date_trunc(month, current_date))
#       AND timestamp >= to_timestamp_ltz('2020-08-01 00:00:00.000 0000','YYYY-MM-DD HH24:MI:SS.FF3 TZHTZM')
#       AND warehouselog.dpo:"WarehouseLogDPO:primary".operationReasonId::int != 10 --SERVER_TYPE_CONSISTENCY_CHECK(10)
# ;
#
# create or replace  view spatra.LOGIN_HISTORY(
# 	EVENT_ID,
# 	EVENT_TIMESTAMP,
# 	EVENT_TYPE,
# 	USER_NAME,
# 	CLIENT_IP,
# 	REPORTED_CLIENT_TYPE,
# 	REPORTED_CLIENT_VERSION,
# 	FIRST_AUTHENTICATION_FACTOR,
# 	SECOND_AUTHENTICATION_FACTOR,
# 	IS_SUCCESS,
# 	ERROR_CODE,
# 	ERROR_MESSAGE,
# 	RELATED_EVENT_ID,
# 	CONNECTION,
#     ACCOUNT_ID,
#     ACCOUNT_NAME
# ) as
#     with
# cust_accounts as (select id,name from snowhouse_import.ie.account_etl_v where replication_group = 'replication_group_value'),
#     error_code as (
#         select key::int as id
#           , value::string as error_code
#         from table(flatten(input => select parse_json(system$dump_enum('ErrorCode')) as error_code))
#       )
#     , client_type as (
#         select key::int as id
#           , value::string as client_type
#         from table(flatten(input => select parse_json(system$dump_enum('ClientType')) as client_type))
#       )
#     , authn_factor_type as (
#         select key::int as id
#           , value::string as authn_factor_type
#         from table(flatten(input => select parse_json(system$dump_enum('AuthnFactorType')) as authn_factor_type))
#       )
#     select
#       authn_event.dpo:"AuthnEventDPO:primary".id::int as event_id
#       , (authn_event.dpo:"AuthnEventDPO:primary".timestamp::int/1000)::timestamp_ltz as event_timestamp
#       , decode(authn_event.dpo:"AuthnEventDPO:primary".eventType::int, 1, 'LOGIN') as event_type
#       , strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".userName)::string as user_name
#       , iff(strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".isTrustedClient)::boolean, '0.0.0.0', strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".clientIP)::string) as client_ip
#       , client_type.client_type as reported_client_type
#       , strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".clientVersion)::string as reported_client_version
#       , factor_type_one.authn_factor_type as first_authentication_factor
#       , factor_type_two.authn_factor_type as second_authentication_factor
#       , iff(strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".isSuccess)::boolean, 'YES', 'NO') as is_success
#       , authn_event.dpo:"AuthnEventDPO:primary".errorCode::int as error_code
#       , error_code.error_code as error_message
#       , authn_event.dpo:"AuthnEventDPO:primary".relatedEventId::int as related_event_id
#       , strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".globalConnectionName)::string as connection
#       , authn_event.dpo:"AuthnEventDPO:primary".accountId::int accountId
#       , cust_accounts.name accountName
#     from snowhouse_import.ie.authn_event_raw_v as authn_event
#     left join error_code
#     on strip_null_value(authn_event.dpo:"AuthnEventDPO:primary":"errorCode")::int = error_code.id
#     left join client_type
#     on authn_event.dpo:"AuthnEventDPO:primary".clientType::int = client_type.id
#     left join authn_factor_type as factor_type_one
#     on authn_event.dpo:"AuthnEventDPO:primary".authnFactor1::int = factor_type_one.id
#     left join authn_factor_type as factor_type_two
#     on authn_event.dpo:"AuthnEventDPO:primary".authnFactor2::int = factor_type_two.id
#     left join cust_accounts on authn_event.dpo:"AuthnEventDPO:primary".accountId::int = cust_accounts.id
#     where authn_event.dpo:"AuthnEventDPO:primary".accountId::int in (select id from cust_accounts) and
#     (authn_event.dpo:"AuthnEventDPO:primary".timestamp::int/1000)::timestamp_ltz >= dateadd(month, -12, date_trunc(month, current_date));

# %%
print('Schema                      : {}'.format(session.get_current_schema()))
# Out:
# Schema                      : "UTIL"

# %%
session.sql("call account_usage_view_deploy('ie','1015_5bd69c04-5f11-49fa-844b-55fb5cebd9a0','spatra')").collect()
# Out:
# [Row(ACCOUNT_USAGE_VIEW_DEPLOY='\ncreate or replace  view spatra.LOGIN_HISTORY(\n\tEVENT_ID,\n\tEVENT_TIMESTAMP,\n\tEVENT_TYPE,\n\tUSER_NAME,\n\tCLIENT_IP,\n\tREPORTED_CLIENT_TYPE,\n\tREPORTED_CLIENT_VERSION,\n\tFIRST_AUTHENTICATION_FACTOR,\n\tSECOND_AUTHENTICATION_FACTOR,\n\tIS_SUCCESS,\n\tERROR_CODE,\n\tERROR_MESSAGE,\n\tRELATED_EVENT_ID,\n\tCONNECTION,\n    ACCOUNT_ID,\n    ACCOUNT_NAME\n) as\n    with \ncust_accounts as (select id,name from snowhouse_import.ie.account_etl_v where replication_group = \'1015_5bd69c04-5f11-49fa-844b-55fb5cebd9a0\'), \n    error_code as (\n        select key::int as id\n          , value::string as error_code\n        from table(flatten(input => select parse_json(system$dump_enum(\'ErrorCode\')) as error_code))\n      )\n    , client_type as (\n        select key::int as id\n          , value::string as client_type\n        from table(flatten(input => select parse_json(system$dump_enum(\'ClientType\')) as client_type))\n      )\n    , authn_factor_type as (\n        select key::int as id\n          , value::string as authn_factor_type\n        from table(flatten(input => select parse_json(system$dump_enum(\'AuthnFactorType\')) as authn_factor_type))\n      )\n    select \n      authn_event.dpo:"AuthnEventDPO:primary".id::int as event_id\n      , (authn_event.dpo:"AuthnEventDPO:primary".timestamp::int/1000)::timestamp_ltz as event_timestamp\n      , decode(authn_event.dpo:"AuthnEventDPO:primary".eventType::int, 1, \'LOGIN\') as event_type\n      , strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".userName)::string as user_name\n      , iff(strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".isTrustedClient)::boolean, \'0.0.0.0\', strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".clientIP)::string) as client_ip\n      , client_type.client_type as reported_client_type\n      , strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".clientVersion)::string as reported_client_version\n      , factor_type_one.authn_factor_type as first_authentication_factor\n      , factor_type_two.authn_factor_type as second_authentication_factor\n      , iff(strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".isSuccess)::boolean, \'YES\', \'NO\') as is_success\n      , authn_event.dpo:"AuthnEventDPO:primary".errorCode::int as error_code\n      , error_code.error_code as error_message\n      , authn_event.dpo:"AuthnEventDPO:primary".relatedEventId::int as related_event_id\n      , strip_null_value(authn_event.dpo:"AuthnEventDPO:primary".globalConnectionName)::string as connection\n      , authn_event.dpo:"AuthnEventDPO:primary".accountId::int accountId\n      , cust_accounts.name accountName\n    from snowhouse_import.ie.authn_event_raw_v as authn_event\n    left join error_code\n    on strip_null_value(authn_event.dpo:"AuthnEventDPO:primary":"errorCode")::int = error_code.id\n    left join client_type\n    on authn_event.dpo:"AuthnEventDPO:primary".clientType::int = client_type.id\n    left join authn_factor_type as factor_type_one\n    on authn_event.dpo:"AuthnEventDPO:primary".authnFactor1::int = factor_type_one.id\n    left join authn_factor_type as factor_type_two\n    on authn_event.dpo:"AuthnEventDPO:primary".authnFactor2::int = factor_type_two.id\n    left join cust_accounts on authn_event.dpo:"AuthnEventDPO:primary".accountId::int = cust_accounts.id\n    where authn_event.dpo:"AuthnEventDPO:primary".accountId::int in (select id from cust_accounts) and \n    (authn_event.dpo:"AuthnEventDPO:primary".timestamp::int/1000)::timestamp_ltz >= dateadd(month, -12, date_trunc(month, current_date));\n')]
